# %% [markdown]
# # Chain of Table Notebook
#
# <a href="https://colab.research.google.com/github/run-llama/llama-hub/blob/main/llama_hub/llama_packs/tables/chain_of_table/chain_of_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# In this notebook we highlight our implementation of the ["Chain of Table" paper by Wang et al.](https://arxiv.org/pdf/2401.04398v1.pdf).
#
# Chain-of-Table proposes the following: given a user query over tabular data, plan out a sequence of tabular operations over the table to retrieve the right information in order to satisfy the user query. The updated table is explicitly used/modified throughout the intermediate chain (unlike chain-of-thought/ReAct which uses generic thoughts).
#
# There is a fixed set of tabular operations that are defined in the paper:
# - `f_add_column`
# - `f_select_row`
# - `f_select_column`
# - `f_group_by`
# - `f_sort_by`
#
# We implemented the paper based on the prompts described in the paper, and adapted it to get it working. That said, this is marked as beta, so there may still be kinks to work through. Do you have suggestions / contributions on how to improve the robustness? Let us know!

# %% [markdown]
# ## Download Data
#
# We use the [WikiTableQuestions dataset](https://ppasupat.github.io/WikiTableQuestions/) (Pasupat and Liang 2015) as our test dataset.
#
# WikiTableQuestions is a question-answering dataset over various semi-structured tables taken from Wikipedia. These tables range in size from a few rows/columns to mnay rows. Some columns may contain multi-part information as well (e.g. a temperature column may contain both Fahrenheight and Celsius).

# %%
# !wget "https://github.com/ppasupat/WikiTableQuestions/releases/download/v1.0.2/WikiTableQuestions-1.0.2-compact.zip" -O data.zip
# !unzip data.zip

# %% [markdown]
# Let's visualize a sample df.

# %%
import pandas as pd

df = pd.read_csv("./WikiTableQuestions/csv/200-csv/3.csv")
df
# Out:
#     Year        Winner  ...             Owner           Breeder
# 0   1919    Sir Barton  ...     J. K. L. Ross               NaN
# 1   1930   Gallant Fox  ...       Belair Stud       Belair Stud
# 2   1935         Omaha  ...       Belair Stud       Belair Stud
# 3   1937   War Admiral  ...  Samuel D. Riddle  Samuel D. Riddle
# 4   1941     Whirlaway  ...      Calumet Farm      Calumet Farm
# 5   1943   Count Fleet  ...      Fannie Hertz      Fannie Hertz
# 6   1946       Assault  ...        King Ranch        King Ranch
# 7   1948      Citation  ...      Calumet Farm      Calumet Farm
# 8   1973   Secretariat  ...     Meadow Stable       Meadow Stud
# 9   1977  Seattle Slew  ...   Karen L. Taylor  Ben S. Castleman
# 10  1978      Affirmed  ...  Harbor View Farm  Harbor View Farm
#
# [11 rows x 6 columns]

# %% [markdown]
# ## Load Pack / Setup
#
# Now we do `download_llama_pack` to load the Chain-Of-Table LlamaPack (you can also import the module directly if using the llama-hub package).
#
# We will also optionally setup observability/tracing so we can observe the intermediate steps.

# %%
# Option: if developing with the llama_hub package
# from llama_hub.llama_packs.tables.chain_of_table.base import (
#     ChainOfTableQueryEngine,
#     serialize_table
# )

# Option: download llama_pack
from llama_index.core.llama_pack import download_llama_pack

download_llama_pack(
    "ChainOfTablePack",
    "./chain_of_table_pack",
    # skip_load=True,
    # leave the below line commented out if using the notebook on main
    # llama_hub_url="https://raw.githubusercontent.com/run-llama/llama-hub/jerry/add_chain_of_table/llama_hub"
)
from chain_of_table_pack.llama_index.packs.tables.chain_of_table.base import ChainOfTableQueryEngine, serialize_table
# Out:
# Processing /home/swaghjal/QA-SAPPlings-Project/chain_of_table_pack
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-packs-tables==0.1.3) (0.10.20.post2)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2024.2.0)
# Requirement already satisfied: httpx in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.8.1)
# Requirement already satisfied: numpy in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.26.0)
# Requirement already satisfied: openai>=1.1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.14.1)
# Requirement already satisfied: pandas in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.1.1)
# Requirement already satisfied: pillow>=9.0.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.16.0)
# Requirement already satisfied: pydantic>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.6.4)
# Requirement already satisfied: anyio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (4.3.0)
# Requirement already satisfied: certifi in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.0.4)
# Requirement already satisfied: idna in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.6)
# Requirement already satisfied: sniffio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.14.0)
# Requirement already satisfied: click in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (8.1.7)
# Requirement already satisfied: joblib in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2023.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (2.16.3)
# Requirement already satisfied: six>=1.5 in /home/swaghjal/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-packs-tables==0.1.3) (1.16.0)
# Building wheels for collected packages: llama-index-packs-tables
#   Building wheel for llama-index-packs-tables (pyproject.toml): started
#   Building wheel for llama-index-packs-tables (pyproject.toml): finished with status 'done'
#   Created wheel for llama-index-packs-tables: filename=llama_index_packs_tables-0.1.3-py3-none-any.whl size=13069 sha256=bdc840f2738424e4e1d104a2ca6809bbb4a0f1a312ae52455310a05005f96609
#   Stored in directory: /tmp/pip-ephem-wheel-cache-36noa7hs/wheels/0d/14/4f/8ea02dca6663b473c5beac4de36240f7c62f0885fcfc887569
# Successfully built llama-index-packs-tables
# Installing collected packages: llama-index-packs-tables
#   Attempting uninstall: llama-index-packs-tables
#     Found existing installation: llama-index-packs-tables 0.1.3
#     Uninstalling llama-index-packs-tables-0.1.3:
#       Successfully uninstalled llama-index-packs-tables-0.1.3
# Successfully installed llama-index-packs-tables-0.1.3

# %%
from llama_index.llms.openai import OpenAI

llm = OpenAI(model="gpt-4-1106-preview",api_key="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")

# %%
# %pip install llama-index-llms-ollama
# Out:
# Collecting llama-index-llms-ollama
#   Downloading llama_index_llms_ollama-0.1.2-py3-none-any.whl.metadata (636 bytes)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-llms-ollama) (0.10.20.post2)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.2.0)
# Requirement already satisfied: httpx in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.8.1)
# Requirement already satisfied: numpy in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.26.0)
# Requirement already satisfied: openai>=1.1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.14.1)
# Requirement already satisfied: pandas in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.1.1)
# Requirement already satisfied: pillow>=9.0.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.0.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Requirement already satisfied: pydantic>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.6.4)
# Requirement already satisfied: anyio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (4.3.0)
# Requirement already satisfied: certifi in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.4)
# Requirement already satisfied: idna in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.6)
# Requirement already satisfied: sniffio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.14.0)
# Requirement already satisfied: click in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (8.1.7)
# Requirement already satisfied: joblib in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2023.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (2.16.3)
# Requirement already satisfied: six>=1.5 in /home/swaghjal/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-llms-ollama) (1.16.0)
# Downloading llama_index_llms_ollama-0.1.2-py3-none-any.whl (3.2 kB)
# Installing collected packages: llama-index-llms-ollama
# Successfully installed llama-index-llms-ollama-0.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install llama-index
# Out:
# Requirement already satisfied: llama-index in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (0.10.20)
# Requirement already satisfied: llama-index-agent-openai<0.2.0,>=0.1.4 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-cli<0.2.0,>=0.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.10)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.20 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.10.20.post2)
# Requirement already satisfied: llama-index-embeddings-openai<0.2.0,>=0.1.5 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.6)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-legacy<0.10.0,>=0.9.48 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.9.48)
# Requirement already satisfied: llama-index-llms-openai<0.2.0,>=0.1.5 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.12)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-program-openai<0.2.0,>=0.1.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.4)
# Requirement already satisfied: llama-index-question-gen-openai<0.2.0,>=0.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: llama-index-readers-file<0.2.0,>=0.1.4 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.11)
# Requirement already satisfied: llama-index-readers-llama-parse<0.2.0,>=0.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index) (0.1.3)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.0.28)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.9.3)
# Requirement already satisfied: dataclasses-json in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (0.6.4)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.0.8)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2024.2.0)
# Requirement already satisfied: httpx in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (0.27.0)
# Requirement already satisfied: llamaindex-py-client<0.2.0,>=0.1.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (0.1.13)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.2.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.26.0)
# Requirement already satisfied: openai>=1.1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (1.14.1)
# Requirement already satisfied: pandas in /home/swaghjal/.local/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2.1.1)
# Requirement already satisfied: pillow>=9.0.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (10.2.0)
# Requirement already satisfied: requests>=2.31.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (0.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (4.66.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (4.10.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-core<0.11.0,>=0.10.20->llama-index) (0.9.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Requirement already satisfied: bs4<0.0.3,>=0.0.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.2)
# Requirement already satisfied: pymupdf<2.0.0,>=1.23.21 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (1.23.26)
# Requirement already satisfied: pypdf<5.0.0,>=4.0.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (0.0.26)
# Requirement already satisfied: llama-parse<0.4.0,>=0.3.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index) (0.3.9)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.20->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from deprecated>=1.2.9.3->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.16.0)
# Requirement already satisfied: pydantic>=1.10 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.6.4)
# Requirement already satisfied: anyio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (4.3.0)
# Requirement already satisfied: certifi in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.0.4)
# Requirement already satisfied: idna in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.6)
# Requirement already satisfied: sniffio in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (0.14.0)
# Requirement already satisfied: click in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.9.0)
# Requirement already satisfied: PyMuPDFb==1.23.22 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pymupdf<2.0.0,>=1.23.21->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (1.23.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.20->llama-index) (3.21.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/swaghjal/.local/lib/python3.9/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (2023.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.2.0)
# Requirement already satisfied: packaging>=17.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.20->llama-index) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/swaghjal/miniconda3/envs/vlra1/lib/python3.9/site-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.13->llama-index-core<0.11.0,>=0.10.20->llama-index) (2.16.3)
# Requirement already satisfied: six>=1.5 in /home/swaghjal/.local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.20->llama-index) (1.16.0)

# %%
from llama_index.llms.ollama import Ollama
llm = Ollama(model="llama2", request_timeout=30.0)

# %% [markdown]
# ### Optional: Setup Observability
#
# Here we will use our Arize Phoenix integration to view traces through the query engine.

# %%
# import phoenix as px
# import llama_index

# px.launch_app()
# llama_index.set_global_handler("arize_phoenix")

# %% [markdown]
# ## Try out some Queries
#
# Now let's try out our `ChainOfTableQueryEngine`!
#
# We run it over a few different tables.

# %% [markdown]
# ### Example: Movie Awards Table

# %%
import pandas as pd

df = pd.read_csv("WikiTableQuestions/csv/200-csv/11.csv")

# %%
df
# Out:
#                                      Award  ...     Result
# 0                     Academy Awards, 1972  ...        Won
# 1                     Academy Awards, 1972  ...        Won
# 2                     Academy Awards, 1972  ...        Won
# 3                     Academy Awards, 1972  ...        Won
# 4                     Academy Awards, 1972  ...        Won
# 5                     Academy Awards, 1972  ...  Nominated
# 6                     Academy Awards, 1972  ...  Nominated
# 7                     Academy Awards, 1972  ...  Nominated
# 8            American Cinema Editors, 1972  ...  Nominated
# 9                              BAFTA, 1972  ...        Won
# 10                             BAFTA, 1972  ...        Won
# 11                             BAFTA, 1972  ...  Nominated
# 12                             BAFTA, 1972  ...  Nominated
# 13                             BAFTA, 1972  ...  Nominated
# 14          David di Donatello Award, 1972  ...        Won
# 15        Directors Guild of America, 1972  ...        Won
# 16            Edgar Allan Poe Awards, 1972  ...        Won
# 17               Golden Globe Awards, 1972  ...        Won
# 18               Golden Globe Awards, 1972  ...        Won
# 19               Golden Globe Awards, 1972  ...        Won
# 20               Golden Globe Awards, 1972  ...  Nominated
# 21   Kansas City Film Critics Circle, 1972  ...        Won
# 22   Kansas City Film Critics Circle, 1972  ...        Won
# 23  National Society of Film Critics, 1972  ...  Nominated
# 24      New York Film Critics Circle, 1971  ...        Won
# 25      New York Film Critics Circle, 1971  ...  Nominated
# 26          Writers Guild of America, 1972  ...  Nominated
#
# [27 rows x 4 columns]

# %%
query_engine = ChainOfTableQueryEngine(df, llm=llm, verbose=True)

# %%
response = query_engine.query("Who won best Director in the 1972 Academy Awards?")
# Out:
# > Iteration: 0
# > Current table:
# col : Award | Category | Nominee | Result
# row 1 : Academy Awards, 1972 | Best Picture | Phillip D'Antoni | Won
# row 2 : Academy Awards, 1972 | Best Director | William Friedkin | Won
# row 3 : Academy Awards, 1972 | Best Actor | Gene Hackman | Won
# row 4 : Academy Awards, 1972 | Best Adapted Screenplay | Ernest Tidyman | Won
# row 5 : Academy Awards, 1972 | Film Editing | Gerald B. Greenberg | Won
# row 6 : Academy Awards, 1972 | Best Supporting Actor | Roy Scheider | Nominated
# row 7 : Academy Awards, 1972 | Best Cinematography | Owen Roizman | Nominated
# row 8 : Academy Awards, 1972 | Best Sound | Theodore Soderberg\nChristopher Newman | Nominated
# row 9 : American Cinema Editors, 1972 | Best Edited Feature Film | Gerald B. Greenberg | Nominated
# row 10 : BAFTA, 1972 | Best Actor | Gene Hackman | Won
# row 11 : BAFTA, 1972 | Best Film Editing | Gerald B. Greenberg | Won
# row 12 : BAFTA, 1972 | Best Direction | William Friedkin | Nominated
# row 13 : BAFTA, 1972 | Best Film | Philip D'Antoni | Nominated
# row 14 : BAFTA, 1972 | Best Sound Track | Christopher Newman\nTheodore Soderberg | Nominated
# row 15 : David di Donatello Award, 1972 | Best Foreign Film | Philip D'Antoni | Won
# row 16 : Directors Guild of America, 1972 | Outstanding Directorial Achievement | William Friedkin | Won
# row 17 : Edgar Allan Poe Awards, 1972 | Best Motion Picture | Ernest Tidyman | Won
# row 18 : Golden Globe Awards, 1972 | Best Motion Picture | Phillip D'Antoni | Won
# row 19 : Golden Globe Awards, 1972 | Best Director | William Friedkin | Won
# row 20 : Golden Globe Awards, 1972 | Best Actor | Gene Hackman | Won
# row 21 : Golden Globe Awards, 1972 | Best Screenplay | Ernest Tidyman | Nominated
# row 22 : Kansas City Film Critics Circle, 1972 | Best Actor | Gene Hackman | Won
# row 23 : Kansas City Film Critics Circle, 1972 | Best Film | Ernest Tidyman | Won
# row 24 : National Society of Film Critics, 1972 | Best Actor | Gene Hackman | Nominated
# row 25 : New York Film Critics Circle, 1971 | Best Actor | Gene Hackman | Won
# row 26 : New York Film Critics Circle, 1971 | Best Film | Ernest Tidyman | Nominated
# row 27 : Writers Guild of America, 1972 | Best Drama Adaptation | Ernest Tidyman | Nominated
#
#
# > New Operation + Args: f_select_row(['row 2'])
# > Current chain: f_select_row(['row 2']) ->
# > Iteration: 1
# > Current table:
# col : Award | Category | Nominee | Result
# row 1 : Academy Awards, 1972 | Best Director | William Friedkin | Won
#
#
# > Ending operation chain.

# %%
str(response.response)
# Out:
# 'assistant: William Friedkin.'

# %% [markdown]
# ### Example: Yearly Temperature and Precipitation
#
# This table is interesting the cells for the first three rows contain two values (e.g. C/F or mm/inches).
#
# Let's see if chain-of-table can handle this question.

# %%
import pandas as pd

df = pd.read_csv("./WikiTableQuestions/csv/200-csv/42.csv")

# %%
df
# Out:
#                        Month             Jan  ...             Dec             Year
# 0       Average high °C (°F)    17.3\n(63.1)  ...    19.2\n(66.6)   24.76\n(76.57)
# 1        Average low °C (°F)     7.9\n(46.2)  ...     8.5\n(47.3)   15.94\n(60.69)
# 2  Precipitation mm (inches)  235.9\n(9.287)  ...  214.5\n(8.445)  857.3\n(33.752)
# 3    Avg. precipitation days            13.9  ...            11.8             63.7
#
# [4 rows x 14 columns]

# %%
query_engine = ChainOfTableQueryEngine(df, llm=llm, verbose=True)

# %%
response = query_engine.query("What was the precipitation in inches during June?")
# Out:
# > Iteration: 0
# > Current table:
# col : Month | Jan | Feb | Mar | Apr | May | Jun | Jul | Aug | Sep | Oct | Nov | Dec | Year
# row 1 : Average high °C (°F) | 17.3\n(63.1) | 19.5\n(67.1) | 22.6\n(72.7) | 25.9\n(78.6) | 27.2\n(81) | 29.3\n(84.7) | 31.8\n(89.2) | 31.4\n(88.5) | 28.9\n(84) | 25.5\n(77.9) | 21.7\n(71.1) | 19.2\n(66.6) | 24.76\n(76.57)
# row 2 : Average low °C (°F) | 7.9\n(46.2) | 9.4\n(48.9) | 12.5\n(54.5) | 17.6\n(63.7) | 19.2\n(66.6) | 21.6\n(70.9) | 23.8\n(74.8) | 22.5\n(72.5) | 20.7\n(69.3) | 16.5\n(61.7) | 14.1\n(57.4) | 8.5\n(47.3) | 15.94\n(60.69)
# row 3 : Precipitation mm (inches) | 235.9\n(9.287) | 129.2\n(5.087) | 82.8\n(3.26) | 33.6\n(1.323) | 4.7\n(0.185) | 0.2\n(0.008) | 0.0\n(0) | 0.2\n(0.008) | 3.2\n(0.126) | 58.0\n(2.283) | 107.4\n(4.228) | 214.5\n(8.445) | 857.3\n(33.752)
# row 4 : Avg. precipitation days | 13.9 | 11.4 | 8.6 | 3.6 | 2.4 | 0.1 | 0.0 | 0.1 | 1.8 | 4.9 | 8.0 | 11.8 | 63.7
#
#
# > New Operation + Args: f_select_row(['row 3'])
# > Current chain: f_select_row(['row 3']) ->
# > Iteration: 1
# > Current table:
# col : Month | Jan | Feb | Mar | Apr | May | Jun | Jul | Aug | Sep | Oct | Nov | Dec | Year
# row 1 : Precipitation mm (inches) | 235.9\n(9.287) | 129.2\n(5.087) | 82.8\n(3.26) | 33.6\n(1.323) | 4.7\n(0.185) | 0.2\n(0.008) | 0.0\n(0) | 0.2\n(0.008) | 3.2\n(0.126) | 58.0\n(2.283) | 107.4\n(4.228) | 214.5\n(8.445) | 857.3\n(33.752)
#
#
# > New Operation + Args: f_select_column(['Jun'])
# > Current chain: f_select_row(['row 3']) -> f_select_column(['Jun']) ->
# > Iteration: 2
# > Current table:
# col : Jun
# row 1 : 0.2\n(0.008)
#
#
# > Ending operation chain.

# %%
str(response)
# Out:
# 'assistant: The answer is: 0.008 inches.\n\nThe table shows the precipitation for the month of June as "0.2" with a notation in parentheses "(0.008)". The number in parentheses is likely the conversion of the precipitation value from one unit to another, in this case from centimeters to inches, given that 0.2 centimeters is equal to 0.07874 inches, which rounds to 0.008 inches when expressed to three significant figures.'

# %% [markdown]
# #### Try out a Baseline
#
# As an example lets take our LLM and see if it can directly answer the question by dumping the table into the prompt!
#
# We can construct this concisely using our query pipeline syntax (you can, of course, just call the prompt/llm directly)

# %%
from llama_index.core.prompts import PromptTemplate
from llama_index.core.query_pipeline import QueryPipeline

prompt_str = """\
Here's a serialized table.

{serialized_table}

Given this table please answer the question: {question}
Answer: """
prompt = PromptTemplate(prompt_str)
prompt_c = prompt.as_query_component(partial={"serialized_table": serialize_table(df)})

# %% [markdown]
# In the response below, we see that the right row is identified, but it mistakenly identifies 0.2 as the inches instead of 0.008.

# %%
qp = QueryPipeline(chain=[prompt_c, llm])
response = qp.run("What was the precipitation in inches during June?")
print(str(response))
# Out:
# assistant: The precipitation in inches during June is given in row 3 under the "Jun" column. According to the table, it is 0.2 inches.

# %% [markdown]
# ### Example

# %%
import pandas as pd

df = pd.read_csv("./WikiTableQuestions/csv/203-csv/114.csv")
df
# Out:
#     Week                Date  ... Record Attendance
# 0      1   September 7, 1998  ...    1–0     74,745
# 1      2  September 13, 1998  ...    2–0     75,013
# 2      3  September 20, 1998  ...    3–0     56,578
# 3      4  September 27, 1998  ...    4–0     71,880
# 4      5     October 4, 1998  ...    5–0     73,218
# 5      6    October 11, 1998  ...    6–0     66,258
# 6      7                 Bye  ...    Bye        Bye
# 7      8    October 25, 1998  ...    7–0     75,217
# 8      9    November 1, 1998  ...    8–0     59,974
# 9     10    November 8, 1998  ...    9–0     74,925
# 10    11   November 16, 1998  ...   10–0     78,100
# 11    12   November 22, 1998  ...   11–0     75,325
# 12    13   November 29, 1998  ...   12–0     66,532
# 13    14    December 6, 1998  ...   13–0     74,962
# 14    15   December 13, 1998  ...   13–1     72,336
# 15    16   December 21, 1998  ...   13–2     74,363
# 16    17   December 27, 1998  ...   14–2     74,057
#
# [17 rows x 8 columns]

# %%
query_engine = ChainOfTableQueryEngine(df, llm=llm, verbose=True)
response = query_engine.query("Which televised ABC game had the greatest attendance?")
# Out:
# > Iteration: 0
# > Current table:
# col : Week | Date | TV Time | Opponent | Result | Game site | Record | Attendance
# row 1 : 1 | September 7, 1998 | ABC 7:00 pm MT | New England Patriots | W 27–21 | Mile High Stadium (ABC) | 1–0 | 74,745
# row 2 : 2 | September 13, 1998 | FOX 2:00 pm MT | Dallas Cowboys | W 42–23 | Mile High Stadium (FOX) | 2–0 | 75,013
# row 3 : 3 | September 20, 1998 | CBS 2:00 pm MT | at Oakland Raiders | W 34–17 | Oakland-Alameda County Coliseum (CBS) | 3–0 | 56,578
# row 4 : 4 | September 27, 1998 | CBS 11:00 am MT | at Washington Redskins | W 38–16 | FedEx Field (CBS) | 4–0 | 71,880
# row 5 : 5 | October 4, 1998 | FOX 2:00 pm MT | Philadelphia Eagles | W 41–16 | Mile High Stadium (FOX) | 5–0 | 73,218
# row 6 : 6 | October 11, 1998 | CBS 2:00 pm MT | at Seattle Seahawks | W 21–16 | Kingdome (CBS) | 6–0 | 66,258
# row 7 : 7 | Bye | Bye | Bye | Bye | Bye | Bye | Bye
# row 8 : 8 | October 25, 1998 | CBS 2:00 pm MT | Jacksonville Jaguars | W 37–24 | Mile High Stadium (CBS) | 7–0 | 75,217
# row 9 : 9 | November 1, 1998 | CBS 11:00 am MT | at Cincinnati Bengals | W 33–26 | Cinergy Field (CBS) | 8–0 | 59,974
# row 10 : 10 | November 8, 1998 | CBS 2:00 pm MT | San Diego Chargers | W 27–10 | Mile High Stadium (CBS) | 9–0 | 74,925
# row 11 : 11 | November 16, 1998 | ABC 7:00 pm MT | at Kansas City Chiefs | W 30–7 | Arrowhead Stadium (ABC) | 10–0 | 78,100
# row 12 : 12 | November 22, 1998 | CBS 2:00 pm MT | Oakland Raiders | W 40–14 | Mile High Stadium (CBS) | 11–0 | 75,325
# row 13 : 13 | November 29, 1998 | ESPN 6:15 pm MT | at San Diego Chargers | W 31–16 | Qualcomm Stadium (ESPN) | 12–0 | 66,532
# row 14 : 14 | December 6, 1998 | CBS 2:00 pm MT | Kansas City Chiefs | W 35–31 | Mile High Stadium (CBS) | 13–0 | 74,962
# row 15 : 15 | December 13, 1998 | CBS 11:00 am MT | at New York Giants | L 16–20 | Giants Stadium (CBS) | 13–1 | 72,336
# row 16 : 16 | December 21, 1998 | ABC 7:00 pm MT | at Miami Dolphins | L 21–31 | Pro Player Stadium (ABC) | 13–2 | 74,363
# row 17 : 17 | December 27, 1998 | CBS 2:15 pm MT | Seattle Seahawks | W 28–21 | Mile High Stadium (CBS) | 14–2 | 74,057
#
#
# > New Operation + Args: f_select_column(['TV Time', 'Attendance'])
# > Current chain: f_select_column(['TV Time', 'Attendance']) ->
# > Iteration: 1
# > Current table:
# col : TV Time | Attendance
# row 1 : ABC 7:00 pm MT | 74,745
# row 2 : FOX 2:00 pm MT | 75,013
# row 3 : CBS 2:00 pm MT | 56,578
# row 4 : CBS 11:00 am MT | 71,880
# row 5 : FOX 2:00 pm MT | 73,218
# row 6 : CBS 2:00 pm MT | 66,258
# row 7 : Bye | Bye
# row 8 : CBS 2:00 pm MT | 75,217
# row 9 : CBS 11:00 am MT | 59,974
# row 10 : CBS 2:00 pm MT | 74,925
# row 11 : ABC 7:00 pm MT | 78,100
# row 12 : CBS 2:00 pm MT | 75,325
# row 13 : ESPN 6:15 pm MT | 66,532
# row 14 : CBS 2:00 pm MT | 74,962
# row 15 : CBS 11:00 am MT | 72,336
# row 16 : ABC 7:00 pm MT | 74,363
# row 17 : CBS 2:15 pm MT | 74,057
#
#
# > New Operation + Args: f_select_row(['row 11'])
# > Current chain: f_select_column(['TV Time', 'Attendance']) -> f_select_row(['row 11']) ->
# > Iteration: 2
# > Current table:
# col : TV Time | Attendance
# row 1 : ABC 7:00 pm MT | 78,100
#
#
# > Ending operation chain.

# %%
print(str(response))
# Out:
# assistant: The answer is: ABC 7:00 pm MT with an attendance of 78,100.

# %% [markdown]
# #### Baseline
#
# Once again, we consider a simple QA prompt baseline and get the wrong answer.

# %%
from llama_index.core.prompts import PromptTemplate
from llama_index.core.query_pipeline import QueryPipeline

prompt_str = """\
Here's a serialized table.

{serialized_table}

Given this table please answer the question: {question}
Answer: """
prompt = PromptTemplate(prompt_str)
prompt_c = prompt.as_query_component(partial={"serialized_table": serialize_table(df)})
qp = QueryPipeline(chain=[prompt_c, llm])
response = qp.run("Which televised ABC game had the greatest attendance?")
print(str(response))
# Out:
# assistant: According to the serialized table, there are two games that were televised on ABC:
#
# - September 7, 1998, against the New England Patriots with an attendance of 74,745.
# - November 16, 1998, against the Kansas City Chiefs with an attendance of 78,100.
#
# The ABC game with the greatest attendance was the November 16, 1998, game against the Kansas City Chiefs at Arrowhead Stadium with an attendance of 78,100.
